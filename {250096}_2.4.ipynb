# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshat-Srivastava-IITK12/-250096-_2.1.ipynb/blob/main/%7B250096%7D_2.4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import yfinance as yf
def SMA(s, w):
  return s.rolling(w).mean()
def EMA(s, w):
  return s.ewm(span = w, adjust = False).mean()
def MACD(s):
  first = 12
  second = 26
  signal = 9
  MACD_line = EMA(s,first) - EMA(s,second)
  Signal_line = EMA(MACD_line, signal)
  return MACD_line, Signal_line
def RSI(s,w):
  delta = s.diff()
  gain = delta.where(delta > 0, 0)
  loss = -delta.where(delta < 0, 0)
  avg_gain = gain.rolling(w).mean()
  avg_loss = loss.rolling(w).mean()
  rs = avg_gain / avg_loss
  rsi = 100 - (100 / (1 + rs))
  return rsi
def Bollinger(s,w = 20):
  middle = SMA(s, w)
  std = s.rolling(w).std()
  upper = middle + 2 * std
  lower = middle - 2 * std
  return middle, upper, lower
def Stochastic_Osc(high, low, close, w):
  lowest = low.rolling(w).min()
  highest = high.rolling(w).max()
  K = 100 * ((close - lowest)/(highest - lowest))
  D = SMA(K,3)
  return K,D

d = yf.download("RELIANCE.NS", period="2y", interval="1d")
close = d['Close']
high = d['High']
low = d['Low']
N = int(input("Enter the period : \n"))
ML, SL = MACD(d)
M,U,L = Bollinger(d)
K, D = Stochastic_Osc(high,low,close,N)
print("SMA is : \n", SMA(d,N).tail())
print("EMA is : \n", EMA(d,N).tail())
print("MACD Line is \n: ", ML.tail())
print("Signal Line is : \n", SL.tail())
print("RSI is : \n", RSI(d,N).tail())
print("The Bollinger Band is : \n", M.tail())
print(U.tail())
print(L.tail())
print("The Oscillator is : \n", K.tail())
print("SMA for 3 day periods of SOC : \n", D.tail())
# Out:
# /tmp/ipython-input-2235002053.py:36: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   d = yf.download("RELIANCE.NS", period="2y", interval="1d")
# [*********************100%***********************]  1 of 1 completed
# Enter the period :
# 56
# SMA is :
#  Price             Close         High          Low         Open        Volume
# Ticker      RELIANCE.NS  RELIANCE.NS  RELIANCE.NS  RELIANCE.NS   RELIANCE.NS
# Date
# 2025-12-15  1476.430363  1486.173220  1466.469639  1475.278573  1.062872e+07
# 2025-12-16  1479.464292  1489.158933  1469.501783  1478.201787  1.063445e+07
# 2025-12-17  1482.442865  1492.146434  1472.596427  1481.380358  1.058512e+07
# 2025-12-18  1485.507150  1495.048220  1475.582140  1484.123215  1.044849e+07
# 2025-12-19  1489.098221  1498.567862  1478.942854  1487.289287  1.043653e+07
# EMA is :
#  Price             Close         High          Low         Open        Volume
# Ticker      RELIANCE.NS  RELIANCE.NS  RELIANCE.NS  RELIANCE.NS   RELIANCE.NS
# Date
# 2025-12-15  1494.530948  1504.421759  1484.305846  1493.608384  1.003129e+07
# 2025-12-16  1496.207057  1506.080643  1486.217923  1495.411598  1.009096e+07
# 2025-12-17  1497.898038  1507.621673  1488.080454  1497.326981  9.986596e+06
# 2025-12-18  1499.529687  1509.161263  1489.733770  1498.655857  9.867096e+06
# 2025-12-19  1501.830399  1511.443322  1491.883462  1500.611793  1.000983e+07
# MACD Line is
# :  Price            Close        High         Low        Open        Volume
# Ticker     RELIANCE.NS RELIANCE.NS RELIANCE.NS RELIANCE.N